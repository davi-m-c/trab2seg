# %%
# Converte uma lista de bytes em uma matriz 4x4
def bytes_to_block(bytes_list):
    matrix = [[0] * 4 for _ in range(4)]
    for i in range(4):
        for j in range(4):
            matrix[j][i] = bytes_list[i * 4 + j]
    return matrix

# %%
# Função para converter uma matriz de estado 4x4 em uma lista de bytes
def block_to_bytes(matrix):
    return [matrix[i][j] for j in range(4) for i in range(4)]

# %%
# Dicionário para a E Table
E_TABLE = {
    0x00: 0x01, 0x01: 0x03, 0x02: 0x05, 0x03: 0x0F, 0x04: 0x11, 0x05: 0x33, 0x06: 0x55, 0x07: 0xFF,
    0x08: 0x1A, 0x09: 0x2E, 0x0A: 0x72, 0x0B: 0x96, 0x0C: 0xA1, 0x0D: 0xF8, 0x0E: 0x13, 0x0F: 0x35,
    0x10: 0x5F, 0x11: 0xE1, 0x12: 0x38, 0x13: 0x48, 0x14: 0xD8, 0x15: 0x73, 0x16: 0x95, 0x17: 0xA4,
    0x18: 0xF7, 0x19: 0x02, 0x1A: 0x06, 0x1B: 0x0A, 0x1C: 0x1E, 0x1D: 0x22, 0x1E: 0x66, 0x1F: 0xAA,
    0x20: 0xE5, 0x21: 0x34, 0x22: 0x5C, 0x23: 0xE4, 0x24: 0x37, 0x25: 0x59, 0x26: 0xEB, 0x27: 0x26,
    0x28: 0x6A, 0x29: 0xBE, 0x2A: 0xD9, 0x2B: 0x70, 0x2C: 0x90, 0x2D: 0xAB, 0x2E: 0xE6, 0x2F: 0x31,
    0x30: 0x53, 0x31: 0xF5, 0x32: 0x04, 0x33: 0x0C, 0x34: 0x14, 0x35: 0x3C, 0x36: 0x44, 0x37: 0xCC,
    0x38: 0x4F, 0x39: 0xD1, 0x3A: 0x68, 0x3B: 0xB8, 0x3C: 0xD3, 0x3D: 0x6E, 0x3E: 0xB2, 0x3F: 0xCD,
    0x40: 0x4C, 0x41: 0xD4, 0x42: 0x67, 0x43: 0xA9, 0x44: 0xE0, 0x45: 0x3B, 0x46: 0x4D, 0x47: 0xD7,
    0x48: 0x62, 0x49: 0xA6, 0x4A: 0xF1, 0x4B: 0x08, 0x4C: 0x18, 0x4D: 0x28, 0x4E: 0x78, 0x4F: 0x88,
    0x50: 0x83, 0x51: 0x9E, 0x52: 0xB9, 0x53: 0xD0, 0x54: 0x6B, 0x55: 0xBD, 0x56: 0xDC, 0x57: 0x7F,
    0x58: 0x81, 0x59: 0x98, 0x5A: 0xB3, 0x5B: 0xCE, 0x5C: 0x49, 0x5D: 0xDB, 0x5E: 0x76, 0x5F: 0x9A,
    0x60: 0xB5, 0x61: 0xC4, 0x62: 0x57, 0x63: 0xF9, 0x64: 0x10, 0x65: 0x30, 0x66: 0x50, 0x67: 0xF0,
    0x68: 0x0B, 0x69: 0x1D, 0x6A: 0x27, 0x6B: 0x69, 0x6C: 0xBB, 0x6D: 0xD6, 0x6E: 0x61, 0x6F: 0xA3,
    0x70: 0xFE, 0x71: 0x19, 0x72: 0x2B, 0x73: 0x7D, 0x74: 0x87, 0x75: 0x92, 0x76: 0xAD, 0x77: 0xEC,
    0x78: 0x2F, 0x79: 0x71, 0x7A: 0x93, 0x7B: 0xAE, 0x7C: 0xE9, 0x7D: 0x20, 0x7E: 0x60, 0x7F: 0xA0,
    0x98: 0x59, 0x99: 0xCB, 0x9A: 0x5F, 0x9B: 0xB0, 0x9C: 0x9C, 0x9D: 0xA9, 0x9E: 0x51, 0x9F: 0xA0,
    0xA0: 0x7F, 0xA1: 0x0C, 0xA2: 0xF6, 0xA3: 0x6F, 0xA4: 0x17, 0xA5: 0xC4, 0xA6: 0x49, 0xA7: 0xEC,
    0xA8: 0xD8, 0xA9: 0x43, 0xAA: 0x1F, 0xAB: 0x2D, 0xAC: 0xA4, 0xAD: 0x76, 0xAE: 0x7B, 0xAF: 0xB7,
    0xB0: 0xCC, 0xB1: 0xBB, 0xB2: 0x3E, 0xB3: 0x5A, 0xB4: 0xFB, 0xB5: 0x60, 0xB6: 0xB1, 0xB7: 0x86,
    0xB8: 0x3B, 0xB9: 0x52, 0xBA: 0xA1, 0xBB: 0x6C, 0xBC: 0xAA, 0xBD: 0x55, 0xBE: 0x29, 0xBF: 0x9D,
    0xC0: 0x97, 0xC1: 0xB2, 0xC2: 0x87, 0xC3: 0x90, 0xC4: 0x61, 0xC5: 0xBE, 0xC6: 0xDC, 0xC7: 0xFC,
    0xC8: 0xBC, 0xC9: 0x95, 0xCA: 0xCF, 0xCB: 0xCD, 0xCC: 0x37, 0xCD: 0x3F, 0xCE: 0x5B, 0xCF: 0xD1,
    0xD0: 0x53, 0xD1: 0x39, 0xD2: 0x84, 0xD3: 0x3C, 0xD4: 0x41, 0xD5: 0xA2, 0xD6: 0x6D, 0xD7: 0x47,
    0xD8: 0x14, 0xD9: 0x2A, 0xDA: 0x9E, 0xDB: 0x5D, 0xDC: 0x56, 0xDD: 0xF2, 0xDE: 0xD3, 0xDF: 0xAB,
    0xE0: 0x44, 0xE1: 0x11, 0xE2: 0x92, 0xE3: 0xD9, 0xE4: 0x23, 0xE5: 0x20, 0xE6: 0x2E, 0xE7: 0x89,
    0xE8: 0xB4, 0xE9: 0x7C, 0xEA: 0xB8, 0xEB: 0x26, 0xEC: 0x77, 0xED: 0x99, 0xEE: 0xE3, 0xEF: 0xA5,
    0xF0: 0x67, 0xF1: 0x4A, 0xF2: 0xED, 0xF3: 0xDE, 0xF4: 0xC5, 0xF5: 0x31, 0xF6: 0xFE, 0xF7: 0x18,
    0xF8: 0x0D, 0xF9: 0x63, 0xFA: 0x8C, 0xFB: 0x80, 0xFC: 0xC0, 0xFD: 0xF7, 0xFE: 0x70, 0xFF: 0x07
}

# %%
# Função para multiplicar uma coluna da matriz de estado com a matriz de multiplicação
def mixcolumns(matrix):
    # Matriz fixa de multiplicação
    multiplication_matrix = [
        [2, 3, 1, 1],
        [1, 2, 3, 1],
        [1, 1, 2, 3],
        [3, 1, 1, 2]
    ]
    
    # Lista para armazenar o resultado
    result = [[0] * 4 for _ in range(4)]
    for i in range(4):
        for j in range(4):
            # Realiza as multiplicação e XOR para calcular cada valor da coluna
            result[i][j] = (
                (matrix[0][j] * multiplication_matrix[i][0]) ^
                (matrix[1][j] * multiplication_matrix[i][1]) ^
                (matrix[2][j] * multiplication_matrix[i][2]) ^
                (matrix[3][j] * multiplication_matrix[i][3])
            ) % 256  # Garante que o resultado seja um byte (8 bits)
    
    return result

# Exemplo de lista de bytes
bytes_list = [162, 234, 172, 170, 42, 170, 234, 186, 138, 168, 42, 234, 106, 155, 168, 170]

# Converte a lista de bytes em uma matriz de estado 4x4
matriz_estado = bytes_to_block(bytes_list)
print("Matriz de Estado antes da operação MixColumns:")
for row in matriz_estado:
    print(row)

# Aplica a operação MixColumns na matriz de estado
matriz_estado_mixed = mixcolumns(matriz_estado)
print("\nMatriz de Estado após a operação MixColumns:")
for row in matriz_estado_mixed:
    print(row)

# Converte a matriz de estado de volta para uma lista de bytes
bytes_list_mixed = block_to_bytes(matriz_estado_mixed)
print("\nLista de bytes após a operação MixColumns:")
print(bytes_list_mixed)
# Out:
# Matriz de Estado antes da operação MixColumns:
# [162, 42, 138, 106]
# [234, 170, 168, 155]
# [172, 234, 42, 168]
# [170, 186, 234, 170]
#
# Matriz de Estado após a operação MixColumns:
# [252, 250, 44, 7]
# [216, 122, 78, 14]
# [238, 122, 200, 95]
# [244, 74, 200, 89]
#
# Lista de bytes após a operação MixColumns:
# [252, 216, 238, 244, 250, 122, 122, 74, 44, 78, 200, 200, 7, 14, 95, 89]

# %%
def mix_columns_inverse(state):
    # Matriz inversa para MixColumns
    inverse_matrix = [
        [0x0E, 0x0B, 0x0D, 0x09],
        [0x09, 0x0E, 0x0B, 0x0D],
        [0x0D, 0x09, 0x0E, 0x0B],
        [0x0B, 0x0D, 0x09, 0x0E]
    ]

    # Lista para armazenar o resultado
    result = [[0] * 4 for _ in range(4)]

    for i in range(4):
        for j in range(4):
            # Realiza as multiplicação e XOR para calcular cada valor da coluna
            result[i][j] = (
                (state[0][j] * inverse_matrix[i][0]) ^
                (state[1][j] * inverse_matrix[i][1]) ^
                (state[2][j] * inverse_matrix[i][2]) ^
                (state[3][j] * inverse_matrix[i][3])
            ) % 256  # Garante que o resultado seja um byte (8 bits)

    return result

# Exemplo de matriz de estado após ShiftRows e SubBytes
state = [252, 216, 238, 244, 250, 122, 122, 74, 44, 78, 200, 200, 7, 14, 95, 89]

state= bytes_to_block(state)

print("Matriz de Estado antes de MixColumnsInverse:")
for row in state:
    print(row)

# Aplica MixColumnsInverse na matriz de estado
state_mixed_inverse = mix_columns_inverse(state)

print("\nMatriz de Estado após MixColumnsInverse:")
for row in state_mixed_inverse:
    print(row)
# Out:
# Matriz de Estado antes de MixColumnsInverse:
# [252, 250, 44, 7]
# [216, 122, 78, 14]
# [238, 122, 200, 95]
# [244, 74, 200, 89]
#
# Matriz de Estado após MixColumnsInverse:
# [2, 58, 18, 10]
# [82, 154, 120, 107]
# [44, 122, 234, 196]
# [42, 202, 234, 114]

# %%
def deshift_rows(matrix):
    for i in range(1, 4):
        matrix[i] = matrix[i][-i:] + matrix[i][:-i]
    return matrix

# Sua lista de bytes 
bytes_list = [162, 170, 42, 170, 42, 168, 168, 170, 138, 155, 172, 186, 106, 234, 234, 234]
# Converte a lista de bytes para uma matriz 4x4
matriz_estado = bytes_to_block(bytes_list)
print("Matriz de Estado:")
for row in matriz_estado:
    print(row)

# Desfaz o ShiftRows na matriz de estado
matriz_estado_deshifted = deshift_rows(matriz_estado)
print("\nMatriz de Estado após o DeshiftRows:")
for row in matriz_estado_deshifted:
    print(row)

# Converte a matriz de estado deslocada de volta para uma lista de bytes

# Cria bytes_list_shifted a partir de matriz_estado_deshifted
bytes_list_shifted = [matriz_estado_deshifted[j][i] for i in range(4) for j in range(4)]

print("\nbytes_list_shifted:")
print(bytes_list_shifted)
# Out:
# Matriz de Estado:
# [162, 42, 138, 106]
# [170, 168, 155, 234]
# [42, 168, 172, 234]
# [170, 170, 186, 234]
#
# Matriz de Estado após o DeshiftRows:
# [162, 42, 138, 106]
# [234, 170, 168, 155]
# [172, 234, 42, 168]
# [170, 186, 234, 170]
#
# bytes_list_shifted:
# [162, 234, 172, 170, 42, 170, 234, 186, 138, 168, 42, 234, 106, 155, 168, 170]

# %%
def shift_rows(matrix):
    # Aplica a operação ShiftRows em uma matriz de estado AES
    for i in range(1, 4):  # Começa a partir da segunda linha (índice 1)
        matrix[i] = matrix[i][i:] + matrix[i][:i]
    return matrix

# Converte a string hexadecimal em uma lista de bytes (cada caractere hexadecimal representa 4 bits)
bytes_list = [162, 170, 42, 170, 42, 168, 168, 170, 138, 155, 172, 186, 106, 234, 234, 234]

# Preenche a matriz 4x4 com os bytes da lista
matriz_estado = bytes_to_block(bytes_list)
print("Matriz de Estado antes do ShiftRows:")
for row in matriz_estado:
    print(row)

# Aplica ShiftRows na matriz de estado (como mencionado anteriormente)
matriz_estado_shifted = shift_rows(matriz_estado)
print("\nMatriz de Estado após o ShiftRows:")
for row in matriz_estado_shifted:
    print(row)

# Cria bytes_list_shifted a partir de matriz_estado_shifted
bytes_list_shifted = [matriz_estado_shifted[j][i] for i in range(4) for j in range(4)]

print("\nbytes_list_shifted:")
print(bytes_list_shifted)
# Out:
# Matriz de Estado antes do ShiftRows:
# [162, 42, 138, 106]
# [170, 168, 155, 234]
# [42, 168, 172, 234]
# [170, 170, 186, 234]
#
# Matriz de Estado após o ShiftRows:
# [162, 42, 138, 106]
# [168, 155, 234, 170]
# [172, 234, 42, 168]
# [234, 170, 170, 186]
#
# bytes_list_shifted:
# [162, 168, 172, 234, 42, 155, 234, 170, 138, 234, 42, 170, 106, 170, 168, 186]

# %%
#Recebe os dados e converte pra binario
data=int(input(),2)
key=input()
#Converte os dados para Hexadecimal
data = hex(data)
print("data:",data)
state = []
#Separa o data em 16 bytes
n=0
x=True
for byte in data[2:]:
    if x ==True:
        state.append(byte)
        n+=1
    else:
        state[n-1]+=byte
    x=not(x)
n=0
for byte in state:
    state[n]=int(byte,16)
    n+=1
print("state:",state)
# Out:
# data: 0xa2aa2aaa2aa8a8aa8a9bacba6aeaeaea
# state: [162, 170, 42, 170, 42, 168, 168, 170, 138, 155, 172, 186, 106, 234, 234, 234]

# %%
# Tabela de substituição Forward AES S-box
forward_s_table = {
    0x00: 0x63, 0x01: 0x7c, 0x02: 0x77, 0x03: 0x7b, 0x04: 0xf2, 0x05: 0x6b, 0x06: 0x6f, 0x07: 0xc5, 0x08: 0x30, 0x09: 0x01, 0x0a: 0x67, 0x0b: 0x2b, 0x0c: 0xfe, 0x0d: 0xd7, 0x0e: 0xab, 0x0f: 0x76,
    0xb0: 0xe7, 0xb1: 0xc8, 0xb2: 0x37, 0xb3: 0x6d, 0xb4: 0x8d, 0xb5: 0xd5, 0xb6: 0x4e, 0xb7: 0xa9, 0xb8: 0x6c, 0xb9: 0x56, 0xba: 0xf4, 0xbb: 0xea, 0xbc: 0x65, 0xbd: 0x7a, 0xbe: 0xae, 0xbf: 0x08,
    0xc0: 0xba, 0xc1: 0x78, 0xc2: 0x25, 0xc3: 0x2e, 0xc4: 0x1c, 0xc5: 0xa6, 0xc6: 0xb4, 0xc7: 0xc6, 0xc8: 0xe8, 0xc9: 0xdd, 0xca: 0x74, 0xcb: 0x1f, 0xcc: 0x4b, 0xcd: 0xbd, 0xce: 0x8b, 0xcf: 0x8a,
    0xd0: 0x70, 0xd1: 0x3e, 0xd2: 0xb5, 0xd3: 0x66, 0xd4: 0x48, 0xd5: 0x03, 0xd6: 0xf6, 0xd7: 0x0e, 0xd8: 0x61, 0xd9: 0x35, 0xda: 0x57, 0xdb: 0xb9, 0xdc: 0x86, 0xdd: 0xc1, 0xde: 0x1d, 0xdf: 0x9e,
    0xe0: 0xe1, 0xe1: 0xf8, 0xe2: 0x98, 0xe3: 0x11, 0xe4: 0x69, 0xe5: 0xd9, 0xe6: 0x8e, 0xe7: 0x94, 0xe8: 0x9b, 0xe9: 0x1e, 0xea: 0x87, 0xeb: 0xe9, 0xec: 0xce, 0xed: 0x55, 0xee: 0x28, 0xef: 0xdf,
    0xf0: 0x8c, 0xf1: 0xa1, 0xf2: 0x89, 0xf3: 0x0d, 0xf4: 0xbf, 0xf5: 0xe6, 0xf6: 0x42, 0xf7: 0x68, 0xf8: 0x41, 0xf9: 0x99, 0xfa: 0x2d, 0xfb: 0x0f, 0xfc: 0xb0, 0xfd: 0x54, 0xfe: 0xbb, 0xff: 0x16
    }

#Muda os bytes de acordo com a tabela, mas usando bytes em decimal
def subbytes(input_bytes):
    output_bytes = bytearray()
    for byte in input_bytes:
        output_bytes.append(forward_s_table[byte])
    #Criando uma lista com os bytes substituidos
    newstate=[]
    n=0
    for byte in output_bytes:
        newstate.append(byte)
        n+=1
        
    print("newstate:",newstate)
    print("Output Bytes after Substitution in Hexadecimal:",output_bytes.hex())
    return newstate

# Exemplos de formatos do input_bytes

#input_bytes = b'\x32\x88\x31\xe0'
#input_bytes = bytes.fromhex(data[2:]) #se data for no formato 0xaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
#input_bytes = [170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170]
print("state :", state)
state = subbytes(state)
# Out:
# state : [170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170]
# newstate: [172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172]
# Output Bytes after Substitution in Hexadecimal: acacacacacacacacacacacacacacacac

# %%
# Tabela de substituição Inverse AES S-box
inverse_s_table = {
    0x00: 0x52, 0x01: 0x09, 0x02: 0x6a, 0x03: 0xd5, 0x04: 0x30, 0x05: 0x36, 0x06: 0xa5, 0x07: 0x38, 0x08: 0xbf, 0x09: 0x40, 0x0a: 0xa3, 0x0b: 0x9e, 0x0c: 0x81, 0x0d: 0xf3, 0x0e: 0xd7, 0x0f: 0xfb,
    0xa0: 0x47, 0xa1: 0xf1, 0xa2: 0x1a, 0xa3: 0x71, 0xa4: 0x1d, 0xa5: 0x29, 0xa6: 0xc5, 0xa7: 0x89, 0xa8: 0x6f, 0xa9: 0xb7, 0xaa: 0x62, 0xab: 0x0e, 0xac: 0xaa, 0xad: 0x18, 0xae: 0xbe, 0xaf: 0x1b,
    0xb0: 0xfc, 0xb1: 0x56, 0xb2: 0x3e, 0xb3: 0x4b, 0xb4: 0xc6, 0xb5: 0xd2, 0xb6: 0x79, 0xb7: 0x20, 0xb8: 0x9a, 0xb9: 0xdb, 0xba: 0xc0, 0xbb: 0xfe, 0xbc: 0x78, 0xbd: 0xcd, 0xbe: 0x5a, 0xbf: 0xf4,
    0xc0: 0x1f, 0xc1: 0xdd, 0xc2: 0xa8, 0xc3: 0x33, 0xc4: 0x88, 0xc5: 0x07, 0xc6: 0xc7, 0xc7: 0x31, 0xc8: 0xb1, 0xc9: 0x12, 0xca: 0x10, 0xcb: 0x59, 0xcc: 0x27, 0xcd: 0x80, 0xce: 0xec, 0xcf: 0x5f,
    0xd0: 0x60, 0xd1: 0x51, 0xd2: 0x7f, 0xd3: 0xa9, 0xd4: 0x19, 0xd5: 0xb5, 0xd6: 0x4a, 0xd7: 0x0d, 0xd8: 0x2d, 0xd9: 0xe5, 0xda: 0x7a, 0xdb: 0x9f, 0xdc: 0x93, 0xdd: 0xc9, 0xde: 0x9c, 0xdf: 0xef,
    0xe0: 0xa0, 0xe1: 0xe0, 0xe2: 0x3b, 0xe3: 0x4d, 0xe4: 0xae, 0xe5: 0x2a, 0xe6: 0xf5, 0xe7: 0xb0, 0xe8: 0xc8, 0xe9: 0xeb, 0xea: 0xbb, 0xeb: 0x3c, 0xec: 0x83, 0xed: 0x53, 0xee: 0x99, 0xef: 0x61,
    0xf0: 0x17, 0xf1: 0x2b, 0xf2: 0x04, 0xf3: 0x7e, 0xf4: 0xba, 0xf5: 0x77, 0xf6: 0xd6, 0xf7: 0x26, 0xf8: 0xe1, 0xf9: 0x69, 0xfa: 0x14, 0xfb: 0x63, 0xfc: 0x55, 0xfd: 0x21, 0xfe: 0x0c, 0xff: 0x7d
}

def resubbytes(input_bytes):
    output_bytes = bytearray()
    for byte in input_bytes:
        output_bytes.append(inverse_s_table[byte])
    #Criando uma lista com os bytes substituidos
    newstate=[]
    n=0
    for byte in output_bytes:
        newstate.append(byte)
        n+=1
        
    print("newstate:",newstate)
    print("Output Bytes after Substitution in Hexadecimal:",output_bytes.hex())
    return newstate

print("state :", state)
state = resubbytes(state)
# Out:
# state : [172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172, 172]
# newstate: [170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170]
# Output Bytes after Substitution in Hexadecimal: aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa

# %%
def keyexpansion(key):
    key+=1
def addroundkey():
    data+=key
def shiftrows():
    data-=1
def mixcolumnsinverse():
    data+=2

# %%
def round(state,last):
    subbytes(state)
    shiftrows(state)
    if last == True:
        pass
    else:
        mixcolumns(state)
    addroundkey(state)

def reverse_round(state,last):
    if last == True:
        pass
    else:
        mixcolumnsinverse(state)
    addroundkey(state)
    resubbytes(state)
    deshift_rows(state)

def encryption(number):
    n=0
    while n < number:
        if n == number:
            round(state,True)
        else:
            round(state,False)
        n+=1

def decryption(number):
    n=0
    while n < number:
        if n == number:
            reverse_round(state,True)
        else:
            reverse_round(state,False)
        n+=1
